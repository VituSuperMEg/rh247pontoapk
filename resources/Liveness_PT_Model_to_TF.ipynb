# %% [markdown]
# # Converting PT models of `Silent-Face-Anti-Spoofing` to TensorFlow Lite
#
# We use the [deepface](https://github.com/serengil/deepface) package to access the PyTorch models and then use the [ai-edge-torch](https://github.com/google-ai-edge/ai-edge-torch/blob/main/docs/pytorch_converter/README.md) package to convert them to the TFLite format.

# %%
# !pip install deepface
# !pip install ai-edge-torch
# Out:
# Collecting deepface
#   Downloading deepface-0.0.95-py3-none-any.whl.metadata (35 kB)
# Collecting requests>=2.27.1 (from deepface)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting numpy>=1.14.0 (from deepface)
#   Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting pandas>=0.23.4 (from deepface)
#   Downloading pandas-2.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (91 kB)
# Collecting gdown>=3.10.1 (from deepface)
#   Downloading gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting tqdm>=4.30.0 (from deepface)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting Pillow>=5.2.0 (from deepface)
#   Downloading pillow-11.3.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.0 kB)
# Collecting opencv-python>=4.5.5.64 (from deepface)
#   Downloading opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (19 kB)
# Collecting tensorflow>=1.9.0 (from deepface)
#   Downloading tensorflow-2.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.5 kB)
# Collecting keras>=2.2.0 (from deepface)
#   Downloading keras-3.11.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting Flask>=1.1.2 (from deepface)
#   Downloading flask-3.1.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting flask-cors>=4.0.1 (from deepface)
#   Downloading flask_cors-6.0.1-py3-none-any.whl.metadata (5.3 kB)
# Collecting mtcnn>=0.1.0 (from deepface)
#   Downloading mtcnn-1.0.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting retina-face>=0.0.14 (from deepface)
#   Downloading retina_face-0.0.17-py3-none-any.whl.metadata (10 kB)
# Collecting fire>=0.4.0 (from deepface)
#   Downloading fire-0.7.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting gunicorn>=20.1.0 (from deepface)
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting termcolor (from fire>=0.4.0->deepface)
#   Downloading termcolor-3.1.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting blinker>=1.9.0 (from Flask>=1.1.2->deepface)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting click>=8.1.3 (from Flask>=1.1.2->deepface)
#   Downloading click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting itsdangerous>=2.2.0 (from Flask>=1.1.2->deepface)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting jinja2>=3.1.2 (from Flask>=1.1.2->deepface)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting markupsafe>=2.1.1 (from Flask>=1.1.2->deepface)
#   Downloading MarkupSafe-3.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting werkzeug>=3.1.0 (from Flask>=1.1.2->deepface)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting beautifulsoup4 (from gdown>=3.10.1->deepface)
#   Downloading beautifulsoup4-4.13.5-py3-none-any.whl.metadata (3.8 kB)
# Collecting filelock (from gdown>=3.10.1->deepface)
#   Downloading filelock-3.19.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: packaging in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from gunicorn>=20.1.0->deepface) (25.0)
# Collecting absl-py (from keras>=2.2.0->deepface)
#   Downloading absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting rich (from keras>=2.2.0->deepface)
#   Downloading rich-14.1.0-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=2.2.0->deepface)
#   Downloading namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting h5py (from keras>=2.2.0->deepface)
#   Downloading h5py-3.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Collecting optree (from keras>=2.2.0->deepface)
#   Downloading optree-0.17.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (33 kB)
# Collecting ml-dtypes (from keras>=2.2.0->deepface)
#   Downloading ml_dtypes-0.5.3-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# Collecting joblib>=1.4.2 (from mtcnn>=0.1.0->deepface)
#   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting lz4>=4.3.3 (from mtcnn>=0.1.0->deepface)
#   Downloading lz4-4.4.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from pandas>=0.23.4->deepface) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas>=0.23.4->deepface)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=0.23.4->deepface)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=0.23.4->deepface) (1.17.0)
# Collecting charset_normalizer<4,>=2 (from requests>=2.27.1->deepface)
#   Downloading charset_normalizer-3.4.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests>=2.27.1->deepface)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.27.1->deepface)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.27.1->deepface)
#   Downloading certifi-2025.8.3-py3-none-any.whl.metadata (2.4 kB)
# Collecting astunparse>=1.6.0 (from tensorflow>=1.9.0->deepface)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow>=1.9.0->deepface)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow>=1.9.0->deepface)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google_pasta>=0.1.1 (from tensorflow>=1.9.0->deepface)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow>=1.9.0->deepface)
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Collecting opt_einsum>=2.3.2 (from tensorflow>=1.9.0->deepface)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting protobuf>=5.28.0 (from tensorflow>=1.9.0->deepface)
#   Downloading protobuf-6.32.0-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting setuptools (from tensorflow>=1.9.0->deepface)
#   Downloading setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: typing_extensions>=3.6.6 in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (4.15.0)
# Collecting wrapt>=1.11.0 (from tensorflow>=1.9.0->deepface)
#   Downloading wrapt-1.17.3-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (6.4 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow>=1.9.0->deepface)
#   Downloading grpcio-1.74.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting tensorboard~=2.20.0 (from tensorflow>=1.9.0->deepface)
#   Downloading tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting markdown>=2.6.8 (from tensorboard~=2.20.0->tensorflow>=1.9.0->deepface)
#   Downloading markdown-3.8.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.20.0->tensorflow>=1.9.0->deepface)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow>=1.9.0->deepface)
#   Downloading wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4->gdown>=3.10.1->deepface)
#   Downloading soupsieve-2.8-py3-none-any.whl.metadata (4.6 kB)
# Collecting PySocks!=1.5.7,>=1.5.6 (from requests[socks]->gdown>=3.10.1->deepface)
#   Downloading PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=2.2.0->deepface)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from rich->keras>=2.2.0->deepface) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=2.2.0->deepface)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading deepface-0.0.95-py3-none-any.whl (128 kB)
# Downloading fire-0.7.1-py3-none-any.whl (115 kB)
# Downloading flask-3.1.2-py3-none-any.whl (103 kB)
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading click-8.2.1-py3-none-any.whl (102 kB)
# Downloading flask_cors-6.0.1-py3-none-any.whl (13 kB)
# Downloading gdown-5.2.0-py3-none-any.whl (18 kB)
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading keras-3.11.3-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 2.0 MB/s  0:00:00 eta 0:00:01
# Downloading MarkupSafe-3.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20 kB)
# Downloading mtcnn-1.0.0-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 19.7 MB/s  0:00:00
# Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading lz4-4.4.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 17.8 MB/s  0:00:00
# Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 25.4 MB/s  0:00:00 eta 0:00:01
# Downloading opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (67.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 19.6 MB/s  0:00:03m0:00:0100:01
# Downloading pandas-2.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 25.4 MB/s  0:00:00m0:00:010:01
# Downloading pillow-11.3.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 30.2 MB/s  0:00:00 eta 0:00:01
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (152 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading certifi-2025.8.3-py3-none-any.whl (161 kB)
# Downloading retina_face-0.0.17-py3-none-any.whl (25 kB)
# Downloading tensorflow-2.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (620.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 620.4/620.4 MB 18.8 MB/s  0:00:30m0:00:0100:01
# Downloading grpcio-1.74.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 29.0 MB/s  0:00:00 eta 0:00:01
# Downloading ml_dtypes-0.5.3-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 30.5 MB/s  0:00:00
# Downloading tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 30.0 MB/s  0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 29.3 MB/s  0:00:00 eta 0:00:01
# Downloading absl_py-2.3.1-py3-none-any.whl (135 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading wheel-0.45.1-py3-none-any.whl (72 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading h5py-3.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 27.9 MB/s  0:00:00
# Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 30.2 MB/s  0:00:00m0:00:0100:01
# Downloading markdown-3.8.2-py3-none-any.whl (106 kB)
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading protobuf-6.32.0-cp39-abi3-manylinux2014_x86_64.whl (322 kB)
# Downloading setuptools-80.9.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 26.8 MB/s  0:00:00
# Downloading termcolor-3.1.0-py3-none-any.whl (7.7 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading wrapt-1.17.3-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (81 kB)
# Downloading beautifulsoup4-4.13.5-py3-none-any.whl (105 kB)
# Downloading soupsieve-2.8-py3-none-any.whl (36 kB)
# Downloading filelock-3.19.1-py3-none-any.whl (15 kB)
# Downloading namex-0.1.0-py3-none-any.whl (5.9 kB)
# Downloading optree-0.17.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (387 kB)
# Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Downloading rich-14.1.0-py3-none-any.whl (243 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: pytz, namex, libclang, flatbuffers, wrapt, wheel, urllib3, tzdata, tqdm, termcolor, tensorboard-data-server, soupsieve, setuptools, PySocks, protobuf, Pillow, optree, opt_einsum, numpy, mdurl, markupsafe, markdown, lz4, joblib, itsdangerous, idna, gunicorn, grpcio, google_pasta, gast, filelock, click, charset_normalizer, certifi, blinker, absl-py, werkzeug, requests, pandas, opencv-python, mtcnn, ml-dtypes, markdown-it-py, jinja2, h5py, fire, beautifulsoup4, astunparse, tensorboard, rich, Flask, keras, gdown, flask-cors, tensorflow, retina-face, deepface
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57/57 [deepface]deepface]tensorflow]]n]
# Successfully installed Flask-3.1.2 Pillow-11.3.0 PySocks-1.7.1 absl-py-2.3.1 astunparse-1.6.3 beautifulsoup4-4.13.5 blinker-1.9.0 certifi-2025.8.3 charset_normalizer-3.4.3 click-8.2.1 deepface-0.0.95 filelock-3.19.1 fire-0.7.1 flask-cors-6.0.1 flatbuffers-25.2.10 gast-0.6.0 gdown-5.2.0 google_pasta-0.2.0 grpcio-1.74.0 gunicorn-23.0.0 h5py-3.14.0 idna-3.10 itsdangerous-2.2.0 jinja2-3.1.6 joblib-1.5.2 keras-3.11.3 libclang-18.1.1 lz4-4.4.4 markdown-3.8.2 markdown-it-py-4.0.0 markupsafe-3.0.2 mdurl-0.1.2 ml-dtypes-0.5.3 mtcnn-1.0.0 namex-0.1.0 numpy-2.2.6 opencv-python-4.12.0.88 opt_einsum-3.4.0 optree-0.17.0 pandas-2.3.2 protobuf-6.32.0 pytz-2025.2 requests-2.32.5 retina-face-0.0.17 rich-14.1.0 setuptools-80.9.0 soupsieve-2.8 tensorboard-2.20.0 tensorboard-data-server-0.7.2 tensorflow-2.20.0 termcolor-3.1.0 tqdm-4.67.1 tzdata-2025.2 urllib3-2.5.0 werkzeug-3.1.3 wheel-0.45.1 wrapt-1.17.3
# Collecting ai-edge-torch
#   Downloading ai_edge_torch-0.6.0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: absl-py in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from ai-edge-torch) (2.3.1)
# Requirement already satisfied: numpy in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from ai-edge-torch) (2.2.6)
# Collecting scipy (from ai-edge-torch)
#   Downloading scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting safetensors (from ai-edge-torch)
#   Downloading safetensors-0.6.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting multipledispatch (from ai-edge-torch)
#   Downloading multipledispatch-1.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting transformers (from ai-edge-torch)
#   Downloading transformers-4.55.4-py3-none-any.whl.metadata (41 kB)
# Collecting kagglehub (from ai-edge-torch)
#   Downloading kagglehub-0.3.13-py3-none-any.whl.metadata (38 kB)
# Collecting tabulate (from ai-edge-torch)
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting torch<2.9.0,>=2.4.0 (from ai-edge-torch)
#   Downloading torch-2.8.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (30 kB)
# Collecting ai-edge-tensorflow==2.21.0.dev20250818 (from ai-edge-torch)
#   Downloading ai_edge_tensorflow-2.21.0.dev20250818-cp310-cp310-manylinux_2_27_x86_64.whl.metadata (4.5 kB)
# Collecting ai-edge-litert==1.4.* (from ai-edge-torch)
#   Downloading ai_edge_litert-1.4.0-cp310-cp310-manylinux_2_17_x86_64.whl.metadata (1.9 kB)
# Collecting ai-edge-quantizer==0.3.* (from ai-edge-torch)
#   Downloading ai_edge_quantizer-0.3.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting jax (from ai-edge-torch)
#   Downloading jax-0.6.2-py3-none-any.whl.metadata (13 kB)
# Collecting torch-xla2>=0.0.1.dev20241201 (from torch-xla2[odml]>=0.0.1.dev20241201->ai-edge-torch)
#   Downloading torch_xla2-0.0.1.dev202412041639-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: astunparse>=1.6.0 in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from ai-edge-tensorflow==2.21.0.dev20250818->ai-edge-torch) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from ai-edge-tensorflow==2.21.0.dev20250818->ai-edge-torch) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from ai-edge-tensorflow==2.21.0.dev20250818->ai-edge-torch) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from ai-edge-tensorflow==2.21.0.dev20250818->ai-edge-torch) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from ai-edge-tensorflow==2.21.0.dev20250818->ai-edge-torch) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from ai-edge-tensorflow==2.21.0.dev20250818->ai-edge-torch) (3.4.0)
# Requirement already satisfied: packaging in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from ai-edge-tensorflow==2.21.0.dev20250818->ai-edge-torch) (25.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from ai-edge-tensorflow==2.21.0.dev20250818->ai-edge-torch) (6.32.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from ai-edge-tensorflow==2.21.0.dev20250818->ai-edge-torch) (2.32.5)
# Requirement already satisfied: setuptools in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from ai-edge-tensorflow==2.21.0.dev20250818->ai-edge-torch) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from ai-edge-tensorflow==2.21.0.dev20250818->ai-edge-torch) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from ai-edge-tensorflow==2.21.0.dev20250818->ai-edge-torch) (3.1.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from ai-edge-tensorflow==2.21.0.dev20250818->ai-edge-torch) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from ai-edge-tensorflow==2.21.0.dev20250818->ai-edge-torch) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from ai-edge-tensorflow==2.21.0.dev20250818->ai-edge-torch) (1.74.0)
# Collecting tb-nightly~=2.20.0.a (from ai-edge-tensorflow==2.21.0.dev20250818->ai-edge-torch)
#   Downloading tb_nightly-2.20.0a20250717-py3-none-any.whl.metadata (1.9 kB)
# Collecting keras-nightly>=3.10.0.dev (from ai-edge-tensorflow==2.21.0.dev20250818->ai-edge-torch)
#   Downloading keras_nightly-3.12.0.dev2025082803-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: h5py>=3.11.0 in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from ai-edge-tensorflow==2.21.0.dev20250818->ai-edge-torch) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from ai-edge-tensorflow==2.21.0.dev20250818->ai-edge-torch) (0.5.3)
# Collecting backports.strenum (from ai-edge-litert==1.4.*->ai-edge-torch)
#   Downloading backports_strenum-1.3.1-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: tqdm in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from ai-edge-litert==1.4.*->ai-edge-torch) (4.67.1)
# Collecting immutabledict (from ai-edge-quantizer==0.3.*->ai-edge-torch)
#   Downloading immutabledict-4.2.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->ai-edge-tensorflow==2.21.0.dev20250818->ai-edge-torch) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->ai-edge-tensorflow==2.21.0.dev20250818->ai-edge-torch) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->ai-edge-tensorflow==2.21.0.dev20250818->ai-edge-torch) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->ai-edge-tensorflow==2.21.0.dev20250818->ai-edge-torch) (2025.8.3)
# Requirement already satisfied: markdown>=2.6.8 in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from tb-nightly~=2.20.0.a->ai-edge-tensorflow==2.21.0.dev20250818->ai-edge-torch) (3.8.2)
# Requirement already satisfied: pillow in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from tb-nightly~=2.20.0.a->ai-edge-tensorflow==2.21.0.dev20250818->ai-edge-torch) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from tb-nightly~=2.20.0.a->ai-edge-tensorflow==2.21.0.dev20250818->ai-edge-torch) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from tb-nightly~=2.20.0.a->ai-edge-tensorflow==2.21.0.dev20250818->ai-edge-torch) (3.1.3)
# Requirement already satisfied: filelock in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from torch<2.9.0,>=2.4.0->ai-edge-torch) (3.19.1)
# Collecting sympy>=1.13.3 (from torch<2.9.0,>=2.4.0->ai-edge-torch)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch<2.9.0,>=2.4.0->ai-edge-torch)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: jinja2 in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from torch<2.9.0,>=2.4.0->ai-edge-torch) (3.1.6)
# Collecting fsspec (from torch<2.9.0,>=2.4.0->ai-edge-torch)
#   Downloading fsspec-2025.7.0-py3-none-any.whl.metadata (12 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93 (from torch<2.9.0,>=2.4.0->ai-edge-torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-runtime-cu12==12.8.90 (from torch<2.9.0,>=2.4.0->ai-edge-torch)
#   Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-cupti-cu12==12.8.90 (from torch<2.9.0,>=2.4.0->ai-edge-torch)
#   Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cudnn-cu12==9.10.2.21 (from torch<2.9.0,>=2.4.0->ai-edge-torch)
#   Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cublas-cu12==12.8.4.1 (from torch<2.9.0,>=2.4.0->ai-edge-torch)
#   Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufft-cu12==11.3.3.83 (from torch<2.9.0,>=2.4.0->ai-edge-torch)
#   Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-curand-cu12==10.3.9.90 (from torch<2.9.0,>=2.4.0->ai-edge-torch)
#   Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cusolver-cu12==11.7.3.90 (from torch<2.9.0,>=2.4.0->ai-edge-torch)
#   Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparse-cu12==12.5.8.93 (from torch<2.9.0,>=2.4.0->ai-edge-torch)
#   Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparselt-cu12==0.7.1 (from torch<2.9.0,>=2.4.0->ai-edge-torch)
#   Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl.metadata (7.0 kB)
# Collecting nvidia-nccl-cu12==2.27.3 (from torch<2.9.0,>=2.4.0->ai-edge-torch)
#   Downloading nvidia_nccl_cu12-2.27.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.8.90 (from torch<2.9.0,>=2.4.0->ai-edge-torch)
#   Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink-cu12==12.8.93 (from torch<2.9.0,>=2.4.0->ai-edge-torch)
#   Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufile-cu12==1.13.1.3 (from torch<2.9.0,>=2.4.0->ai-edge-torch)
#   Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.4.0 (from torch<2.9.0,>=2.4.0->ai-edge-torch)
#   Downloading triton-3.4.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from astunparse>=1.6.0->ai-edge-tensorflow==2.21.0.dev20250818->ai-edge-torch) (0.45.1)
# Requirement already satisfied: rich in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from keras-nightly>=3.10.0.dev->ai-edge-tensorflow==2.21.0.dev20250818->ai-edge-torch) (14.1.0)
# Requirement already satisfied: namex in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from keras-nightly>=3.10.0.dev->ai-edge-tensorflow==2.21.0.dev20250818->ai-edge-torch) (0.1.0)
# Requirement already satisfied: optree in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from keras-nightly>=3.10.0.dev->ai-edge-tensorflow==2.21.0.dev20250818->ai-edge-torch) (0.17.0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch<2.9.0,>=2.4.0->ai-edge-torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting pytest (from torch-xla2>=0.0.1.dev20241201->torch-xla2[odml]>=0.0.1.dev20241201->ai-edge-torch)
#   Downloading pytest-8.4.1-py3-none-any.whl.metadata (7.7 kB)
# Collecting jaxlib<=0.6.2,>=0.6.2 (from jax->ai-edge-torch)
#   Downloading jaxlib-0.6.2-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from werkzeug>=1.0.1->tb-nightly~=2.20.0.a->ai-edge-tensorflow==2.21.0.dev20250818->ai-edge-torch) (3.0.2)
# Collecting pyyaml (from kagglehub->ai-edge-torch)
#   Downloading PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: exceptiongroup>=1 in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from pytest->torch-xla2>=0.0.1.dev20241201->torch-xla2[odml]>=0.0.1.dev20241201->ai-edge-torch) (1.3.0)
# Collecting iniconfig>=1 (from pytest->torch-xla2>=0.0.1.dev20241201->torch-xla2[odml]>=0.0.1.dev20241201->ai-edge-torch)
#   Downloading iniconfig-2.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting pluggy<2,>=1.5 (from pytest->torch-xla2>=0.0.1.dev20241201->torch-xla2[odml]>=0.0.1.dev20241201->ai-edge-torch)
#   Downloading pluggy-1.6.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: pygments>=2.7.2 in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from pytest->torch-xla2>=0.0.1.dev20241201->torch-xla2[odml]>=0.0.1.dev20241201->ai-edge-torch) (2.19.2)
# Collecting tomli>=1 (from pytest->torch-xla2>=0.0.1.dev20241201->torch-xla2[odml]>=0.0.1.dev20241201->ai-edge-torch)
#   Downloading tomli-2.2.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from rich->keras-nightly>=3.10.0.dev->ai-edge-tensorflow==2.21.0.dev20250818->ai-edge-torch) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras-nightly>=3.10.0.dev->ai-edge-tensorflow==2.21.0.dev20250818->ai-edge-torch) (0.1.2)
# Collecting huggingface-hub<1.0,>=0.34.0 (from transformers->ai-edge-torch)
#   Downloading huggingface_hub-0.34.4-py3-none-any.whl.metadata (14 kB)
# Collecting regex!=2019.12.17 (from transformers->ai-edge-torch)
#   Downloading regex-2025.7.34-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Collecting tokenizers<0.22,>=0.21 (from transformers->ai-edge-torch)
#   Downloading tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting hf-xet<2.0.0,>=1.1.3 (from huggingface-hub<1.0,>=0.34.0->transformers->ai-edge-torch)
#   Downloading hf_xet-1.1.9-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.7 kB)
# Downloading ai_edge_torch-0.6.0-py3-none-any.whl (439 kB)
# Downloading ai_edge_tensorflow-2.21.0.dev20250818-cp310-cp310-manylinux_2_27_x86_64.whl (253.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.9/253.9 MB 10.2 MB/s  0:00:24m0:00:0100:01
# Downloading ai_edge_litert-1.4.0-cp310-cp310-manylinux_2_17_x86_64.whl (11.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 9.7 MB/s  0:00:01m eta 0:00:01
# Downloading ai_edge_quantizer-0.3.0-py3-none-any.whl (192 kB)
# Downloading tb_nightly-2.20.0a20250717-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 12.3 MB/s  0:00:00 eta 0:00:01
# Downloading torch-2.8.0-cp310-cp310-manylinux_2_28_x86_64.whl (888.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 888.0/888.0 MB 24.0 MB/s  0:00:32m0:00:0100:01
# Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 22.2 MB/s  0:00:24m0:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 16.5 MB/s  0:00:00m0:00:010:01
# Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 20.8 MB/s  0:00:04m0:00:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 15.8 MB/s  0:00:00
# Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 16.0 MB/s  0:00:39m0:00:0100:01
# Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 20.0 MB/s  0:00:09m0:00:0100:01
# Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 16.7 MB/s  0:00:00
# Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 23.8 MB/s  0:00:02m0:00:0100:01
# Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 23.2 MB/s  0:00:11m0:00:0100:01
# Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 27.3 MB/s  0:00:10m0:00:0100:01
# Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 MB 24.7 MB/s  0:00:11m0:00:0100:01
# Downloading nvidia_nccl_cu12-2.27.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.4/322.4 MB 23.9 MB/s  0:00:12m0:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 29.6 MB/s  0:00:01m0:00:0100:01
# Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Downloading triton-3.4.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.4/155.4 MB 26.2 MB/s  0:00:05m0:00:0100:01
# Downloading keras_nightly-3.12.0.dev2025082803-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 11.8 MB/s  0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 27.4 MB/s  0:00:00m0:00:01
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 21.3 MB/s  0:00:00
# Downloading torch_xla2-0.0.1.dev202412041639-py3-none-any.whl (76 kB)
# Downloading jax-0.6.2-py3-none-any.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 19.4 MB/s  0:00:00
# Downloading jaxlib-0.6.2-cp310-cp310-manylinux2014_x86_64.whl (89.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 MB 14.1 MB/s  0:00:06m0:00:0100:01
# Downloading scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 16.9 MB/s  0:00:02m0:00:0100:01
# Downloading backports_strenum-1.3.1-py3-none-any.whl (8.3 kB)
# Downloading fsspec-2025.7.0-py3-none-any.whl (199 kB)
# Downloading immutabledict-4.2.1-py3-none-any.whl (4.7 kB)
# Downloading kagglehub-0.3.13-py3-none-any.whl (68 kB)
# Downloading multipledispatch-1.0.0-py3-none-any.whl (12 kB)
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 21.2 MB/s  0:00:00
# Downloading pytest-8.4.1-py3-none-any.whl (365 kB)
# Downloading pluggy-1.6.0-py3-none-any.whl (20 kB)
# Downloading iniconfig-2.1.0-py3-none-any.whl (6.0 kB)
# Downloading tomli-2.2.1-py3-none-any.whl (14 kB)
# Downloading PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (751 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 751.2/751.2 kB 20.4 MB/s  0:00:00
# Downloading safetensors-0.6.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (485 kB)
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading transformers-4.55.4-py3-none-any.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 21.6 MB/s  0:00:00 eta 0:00:01
# Downloading huggingface_hub-0.34.4-py3-none-any.whl (561 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.5/561.5 kB 19.6 MB/s  0:00:00
# Downloading hf_xet-1.1.9-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 20.2 MB/s  0:00:00
# Downloading tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 19.8 MB/s  0:00:00
# Downloading regex-2025.7.34-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (789 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 789.8/789.8 kB 13.2 MB/s  0:00:00
# Installing collected packages: nvidia-cusparselt-cu12, multipledispatch, mpmath, triton, tomli, tabulate, sympy, scipy, safetensors, regex, pyyaml, pluggy, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, networkx, iniconfig, immutabledict, hf-xet, fsspec, backports.strenum, tb-nightly, pytest, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, kagglehub, jaxlib, huggingface-hub, ai-edge-litert, tokenizers, nvidia-cusolver-cu12, keras-nightly, jax, transformers, torch, ai-edge-tensorflow, torch-xla2, ai-edge-quantizer, ai-edge-torch
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46/46 [ai-edge-torch]ge-torch]ge-quantizer]]2]2]
# Successfully installed ai-edge-litert-1.4.0 ai-edge-quantizer-0.3.0 ai-edge-tensorflow-2.21.0.dev20250818 ai-edge-torch-0.6.0 backports.strenum-1.3.1 fsspec-2025.7.0 hf-xet-1.1.9 huggingface-hub-0.34.4 immutabledict-4.2.1 iniconfig-2.1.0 jax-0.6.2 jaxlib-0.6.2 kagglehub-0.3.13 keras-nightly-3.12.0.dev2025082803 mpmath-1.3.0 multipledispatch-1.0.0 networkx-3.4.2 nvidia-cublas-cu12-12.8.4.1 nvidia-cuda-cupti-cu12-12.8.90 nvidia-cuda-nvrtc-cu12-12.8.93 nvidia-cuda-runtime-cu12-12.8.90 nvidia-cudnn-cu12-9.10.2.21 nvidia-cufft-cu12-11.3.3.83 nvidia-cufile-cu12-1.13.1.3 nvidia-curand-cu12-10.3.9.90 nvidia-cusolver-cu12-11.7.3.90 nvidia-cusparse-cu12-12.5.8.93 nvidia-cusparselt-cu12-0.7.1 nvidia-nccl-cu12-2.27.3 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvtx-cu12-12.8.90 pluggy-1.6.0 pytest-8.4.1 pyyaml-6.0.2 regex-2025.7.34 safetensors-0.6.2 scipy-1.15.3 sympy-1.14.0 tabulate-0.9.0 tb-nightly-2.20.0a20250717 tokenizers-0.21.4 tomli-2.2.1 torch-2.8.0 torch-xla2-0.0.1.dev202412041639 transformers-4.55.4 triton-3.4.0

# %%
# !mkdir -p /root/.deepface/weights
# Out:
# mkdir: não foi possível criar o diretório “/root”: Permissão negada

# %%
from deepface.models.spoofing.FasNet import Fasnet

fasnet = Fasnet()
print(type(fasnet.first_model))
print(type(fasnet.second_model))
# Out:
# 2025-08-28 12:10:11.834261: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from deepface.models.spoofing.FasNet import Fasnet
#       3 fasnet = Fasnet()
#       4 print(type(fasnet.first_model))
#
# File ~/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages/deepface/models/spoofing/FasNet.py:9
#       6 import numpy as np
#       8 # project dependencies
# ----> 9 from deepface.commons import weight_utils
#      10 from deepface.commons.logger import Logger
#      12 logger = Logger()
#
# File ~/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages/deepface/commons/weight_utils.py:11
#       8 import gdown
#      10 # project dependencies
# ---> 11 from deepface.commons import folder_utils, package_utils
#      12 from deepface.commons.logger import Logger
#      15 tf_version = package_utils.get_tf_major_version()
#
# File ~/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages/deepface/commons/package_utils.py:5
#       2 import hashlib
#       4 # 3rd party dependencies
# ----> 5 import tensorflow as tf
#       7 # package dependencies
#       8 from deepface.commons.logger import Logger
#
# File ~/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages/tensorflow/__init__.py:55
#      53 from tensorflow._api.v2 import autograph
#      54 from tensorflow._api.v2 import bitwise
# ---> 55 from tensorflow._api.v2 import compat
#      56 from tensorflow._api.v2 import config
#      57 from tensorflow._api.v2 import data
#
# File ~/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages/tensorflow/_api/v2/compat/__init__.py:8
#       3 """Public API for tf._api.v2.compat namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.compat import v1
#       9 from tensorflow._api.v2.compat import v2
#      10 from tensorflow.python.compat.compat import forward_compatibility_horizon # line: 125
#
# File ~/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages/tensorflow/_api/v2/compat/v1/__init__.py:30
#      28 from tensorflow._api.v2.compat.v1 import autograph
#      29 from tensorflow._api.v2.compat.v1 import bitwise
# ---> 30 from tensorflow._api.v2.compat.v1 import compat
#      31 from tensorflow._api.v2.compat.v1 import config
#      32 from tensorflow._api.v2.compat.v1 import data
#
# File ~/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages/tensorflow/_api/v2/compat/v1/compat/__init__.py:8
#       3 """Public API for tf._api.v2.compat namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.compat.v1.compat import v1
#       9 from tensorflow._api.v2.compat.v1.compat import v2
#      10 from tensorflow.python.compat.compat import forward_compatibility_horizon # line: 125
#
# File ~/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages/tensorflow/_api/v2/compat/v1/compat/v1/__init__.py:47
#      45 from tensorflow._api.v2.compat.v1 import layers
#      46 from tensorflow._api.v2.compat.v1 import linalg
# ---> 47 from tensorflow._api.v2.compat.v1 import lite
#      48 from tensorflow._api.v2.compat.v1 import logging
#      49 from tensorflow._api.v2.compat.v1 import lookup
#
# File ~/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages/tensorflow/_api/v2/compat/v1/lite/__init__.py:9
#       6 import sys as _sys
#       8 from tensorflow._api.v2.compat.v1.lite import constants
# ----> 9 from tensorflow._api.v2.compat.v1.lite import experimental
#      10 from tensorflow.lite.python.convert import OpsSet # line: 153
#      11 from tensorflow.lite.python.convert import toco_convert # line: 946
#
# File ~/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages/tensorflow/_api/v2/compat/v1/lite/experimental/__init__.py:8
#       3 """Public API for tf._api.v2.lite.experimental namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.compat.v1.lite.experimental import authoring
#       9 from tensorflow.lite.python.analyzer import ModelAnalyzer as Analyzer # line: 35
#      10 from tensorflow.lite.python.interpreter import OpResolverType # line: 315
#
# File ~/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages/tensorflow/_api/v2/compat/v1/lite/experimental/authoring/__init__.py:8
#       3 """Public API for tf._api.v2.lite.experimental.authoring namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow.lite.python.authoring.authoring import compatible # line: 263
#      10 from tensorflow.python.util import module_wrapper as _module_wrapper
#      12 if not isinstance(_sys.modules[__name__], _module_wrapper.TFModuleWrapper):
#
# File ~/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages/tensorflow/lite/python/authoring/authoring.py:42
#      40 from tensorflow.compiler.mlir.lite.metrics import converter_error_data_pb2
#      41 # pylint: disable=g-import-not-at-top
# ---> 42 from tensorflow.lite.python import convert
#      43 from tensorflow.lite.python import lite
#      44 from tensorflow.python.util.tf_export import tf_export as _tf_export
#
# File ~/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages/tensorflow/lite/python/convert.py:36
#      34 from tensorflow.lite.python.convert_phase import ConverterError
#      35 from tensorflow.lite.python.convert_phase import SubComponent
# ---> 36 from tensorflow.lite.python.metrics.wrapper import metrics_wrapper as _metrics_wrapper
#      37 from tensorflow.lite.tools import flatbuffer_utils
#      38 from tensorflow.python.framework import dtypes
#
# File ~/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages/tensorflow/lite/python/metrics/wrapper/metrics_wrapper.py:19
#      17 from tensorflow.compiler.mlir.lite.metrics import converter_error_data_pb2
#      18 from tensorflow.compiler.mlir.lite.python import wrap_converter
# ---> 19 from tensorflow.lite.python.metrics._pywrap_tensorflow_lite_metrics_wrapper import MetricsWrapper  # pylint: disable=unused-import
#      22 def retrieve_collected_errors():
#      23   """Returns and clears the list of collected errors in ErrorCollector.
#      24
#      25   The RetrieveCollectedErrors function in C++ returns a list of serialized proto
#    (...)
#      29     A list of ConverterErrorData.
#      30   """
#
# ImportError: /home/vitu/AndroidStudioProjects/OnDevice-Face-Recognition-Android/.venv/lib/python3.10/site-packages/tensorflow/lite/python/metrics/_pywrap_tensorflow_lite_metrics_wrapper.so: undefined symbol: Wrapped_PyInit__pywrap_tensorflow_lite_metrics_wrapper

# %%
import torch
import ai_edge_torch

sample_inputs = ( torch.randn(1, 80, 80, 3) , )
model = ai_edge_torch.to_channel_last_io(fasnet.first_model.eval(), args=[0])
edge_model = ai_edge_torch.convert(model, sample_inputs)
edge_model.export("first_model.tflite")

# %%
sample_inputs = ( torch.randn(1, 80, 80, 3) , )
model = ai_edge_torch.to_channel_last_io(fasnet.second_model.eval(), args=[0])
edge_model = ai_edge_torch.convert(model, sample_inputs)
edge_model.export("second_model.tflite")

# %%
import tensorflow as tf
import pprint

interpreter = tf.lite.Interpreter("first_model.tflite")
interpreter.allocate_tensors()
pprint.pprint(interpreter.get_input_details())
pprint.pprint(interpreter.get_output_details())

# %%
import tensorflow as tf
import pprint

interpreter = tf.lite.Interpreter("second_model.tflite")
interpreter.allocate_tensors()
pprint.pprint(interpreter.get_input_details())
pprint.pprint(interpreter.get_output_details())

# %%
from google.colab import files

files.download('first_model.tflite')
files.download('second_model.tflite')
